# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.rc('axes', unicode_minus=False)
plt.rc('font', family='Malgun Gothic')

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('data/train.csv')

# %%
train.head()
# Out:
#            ID   quarter department       day  targeted_productivity    smv  \
# 0  TRAIN_0000  Quarter1     sweing  Thursday                   0.80  26.16
# 1  TRAIN_0001  Quarter1  finishing  Thursday                   0.75   3.94
# 2  TRAIN_0002  Quarter1     sweing  Thursday                   0.80  11.41
# 3  TRAIN_0003  Quarter1     sweing  Thursday                   0.80  11.41
# 4  TRAIN_0004  Quarter1     sweing  Thursday                   0.80  25.90
#
#     wip  over_time  incentive  idle_time  idle_men  no_of_style_change  \
# 0  1108    0.27315         98          0         0                   0
# 1  1190    0.03704          0          0         0                   0
# 2   968    0.14120         50          0         0                   0
# 3   968    0.14120         50          0         0                   0
# 4  1170    0.07407         50          0         0                   0
#
#    no_of_workers  actual_productivity
# 0             59              0.94073
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   targeted_productivity  1197 non-null   float64
#  5   smv                    1197 non-null   float64
#  6   wip                    1197 non-null   int64
#  7   over_time              1197 non-null   float64
#  8   incentive              1197 non-null   int64
#  9   idle_time              1197 non-null   int64
#  10  idle_men               1197 non-null   int64
#  11  no_of_style_change     1197 non-null   int64
#  12  no_of_workers          1197 non-null   int64
#  13  actual_productivity    1197 non-null   float64
# dtypes: float64(4), int64(6), object(4)
# ...

# %%
train.describe()
# Out:
#        targeted_productivity          smv           wip    over_time  \
# count            1197.000000  1197.000000   1197.000000  1197.000000
# mean                0.729632    15.062172   1190.269006     0.176214
# std                 0.097891    10.943219   1395.647280     0.129197
# min                 0.070000     2.900000      7.000000     0.000000
# 25%                 0.700000     3.940000    970.000000     0.055560
# 50%                 0.750000    15.260000   1190.000000     0.152780
# 75%                 0.800000    24.260000   1190.000000     0.268520
# max                 0.800000    54.560000  23122.000000     1.000000
#
#          incentive    idle_time     idle_men  no_of_style_change  \
# count  1197.000000  1197.000000  1197.000000         1197.000000
# mean     38.210526     0.727652     0.369256            0.150376
# std     160.182643    12.709094     3.268987            0.427848
# min       0.000000     0.000000     0.000000            0.000000
# ...

# %%
info = pd.read_csv('data/column_info.csv')
info
# Out:
#                   Column명                                           설명
# 0                      ID                                        샘플 ID
# 1                 quarter  한 달을 4개의 기간으로 분할한 단위 (예시: 1주차, 2주차, 3주차 ..)
# 2              department                                   인스턴스 관련 부서
# 3                     day                                           요일
# 4   targeted_productivity                                   설정한 목표 생산성
# 5                     smv                               작업에 할당된 시간 (분)
# 6                     wip           작업 진행 중인 품목 수 (제품에 대한 미완성 품목 수 포함)
# 7               over_time                          각 팀별 초과 근무 정도 (0~1)
# 8               incentive                          재정적 인센티브 양 (BDT 단위)
# 9               idle_time                                   생산이 중단된 시간
# 10               idle_men                               생산 중단으로 유휴인원 수
# 11     no_of_style_change                             특정 제품의 스타일 변경 횟수
# ...

# %%
train.columns
# Out:
# Index(['ID', 'quarter', 'department', 'day', 'targeted_productivity', 'smv',
#        'wip', 'over_time', 'incentive', 'idle_time', 'idle_men',
#        'no_of_style_change', 'no_of_workers', 'actual_productivity'],
#       dtype='object')

# %%
for col in train.columns[1:]:
    plt.figure(figsize=(3,3))
    sns.displot(train[col])
    plt.title(info.loc[info['Column명']==col]['설명'].item())
    plt.show()
    print(train[col].value_counts())
# Out:
# Quarter1    360
# Quarter2    335
# Quarter4    248
# Quarter3    210
# Quarter5     44
# Name: quarter, dtype: int64
# sweing       691
# finishing    506
# Name: department, dtype: int64
# Wednesday    208
# Sunday       203
# Tuesday      201
# Thursday     199
# Monday       199
# Saturday     187
# Name: day, dtype: int64
# 0.80    540
# 0.70    242
# 0.75    216
# 0.65     63
# 0.60     57
# 0.50     49
# 0.35     27
# 0.40      2
# 0.07      1
# Name: targeted_productivity, dtype: int64
# 3.94     192
# 2.90     108
# 22.52    103
# 30.10     79
# 4.15      76
#         ...
# 48.68      1
# 54.56      1
# 41.19      1
# 49.10      1
# 40.99      1
# Name: smv, Length: 70, dtype: int64
# 1190    506
# 1039      5
# 1282      4
# 1422      3
# 1216      3
#        ...
# 1635      1
# 1519      1
# 1337      1
# 1118      1
# 914       1
# Name: wip, Length: 549, dtype: int64
# 0.03704    129
# 0.05556    111
# 0.26852     61
# 0.26389     48
# 0.04630     39
#           ...
# ...

# %%
sns.pairplot(train)
plt.show()

# %%
sns.heatmap(train.corr(), annot=True, linewidth=5, cmap='Blues')
plt.show()

# %% [markdown]
# - smv와 no_of_workers가 가장 상관관계가 높음

# %% [markdown]
# ### 팀별 작업자 수(no_of_workers)별 작업시간(smv)

# %%
sns.barplot(train['no_of_workers'], train['smv'])
plt.xticks(rotation=90)
plt.show()

# %%
num_col = ['targeted_productivity', 'smv', 'wip', 'over_time', 'incentive', 'idle_time', 'idle_men', 'no_of_style_change', 'no_of_workers', 'actual_productivity']

fig = plt.figure(figsize=(10,5))
rosw=2
cols=5

for i, col in enumerate(num_col):
    ax = fig.add_subplot(rows, cols, i+1)
    ax.boxplot(train[col])
    ax.set_title(info[info['Column명']==col]['설명'].item())
plt.tight_layout()

# %%
def vibox(var):
    _=plt.figure(figsize=(5,8))
    _=plt.violinplot(var, data=train)
    _=plt.boxplot(var, data=train)
    _=plt.title(f'{var} 이상치 및 분포')

# %%
fig = plt.figure(figsize=(15,8))
rows=2
cols = 5
for enu, i in enumerate(num_col):
    ax = fig.add_subplot(rows, cols, enu+1)
    _ = ax.violinplot(i, data=train)
    _ = ax.boxplot(i, data=train)
    _ = ax.set_title(i + '이상치 및 분포')
plt.tight_layout()
